# %%
import psycopg2
from psycopg2 import Error
import os
import csv

# %%
def connect_to_db(username='postgres', password='test', host='127.0.0.1', port='5432', database='WordsDatabase'):
    try:
        # Connect to an existing database
        connection = psycopg2.connect(user=username,
                                      password=password,
                                      host=host,
                                      port=port,
                                      database=database)

        # Create a cursor to perform database operations
        cursor = connection.cursor()
        print("connected to the database")

        return cursor, connection
    except (Exception, Error) as error:
        print("Error while connecting to PostgreSQL", error)

# %%
def disconnect_from_db(connection,cursor):
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed.")
    else:
    	print("Connection does not work.")

# %%
def run_and_fetch_sql(cursor, sql_string="select * from arabicid"):
    try:
        # Executing a SQL query
        cursor.execute(sql_string)
        # Fetch result
        record = cursor.fetchall()
        return record
    
    except (Exception, Error) as error:
        print("Errors while executes the code: ", error)
        return -1

# %%
def run_and_commit_sql(cursor, connection, sql_string=""):
    try:
        # Executing a SQL query
        cursor.execute(sql_string)
        # if some changes are made, you need to commit your changes
        connection.commit()
        # use 1 to represent success
        return 1
    except (Exception, Error) as error:
        print("Errors while executes the code: ", error)
        return -1

# %%
def insert_word(table_name, id, lang, word):
    cursor, connection = connect_to_db()
    # execute SQL commands
    # record = run_and_commit_sql(cursor,connection, f"INSERT INTO {table_name} (wordid, langauge, word) VALUES ({id},{lang},{word});")
    command = "INSERT INTO " + table_name + "(wordid, langauge, word) VALUES ("+ id + ","" + lang + ","" + word + "};"
    # insert into arabicid (wordid, langauge, word) values (0,'arabic', 'الذي - التي' )
    print(f"INSERT INTO {table_name} (wordid, langauge, word) VALUES ({id},""{{lang}"",""{word}"");")

    # if record == -1:
    #     print('Something is wrong with the SQL command')
    # else:
    #     connection.commit()
        
    # disconnect from database
    disconnect_from_db(connection,cursor)

# %%
cursor, connection = connect_to_db()
 # execute SQL commands
record = run_and_fetch_sql(cursor)
if record == -1:
    print('Something is wrong with the SQL command')
else:
    # this will return all column names of the select result table
    col_names = [desc[0] for desc in cursor.description]
    # only use the first five rows
    log = record[:5]
    print(log)
    # disconnect from database
disconnect_from_db(connection, cursor)
# Out:
# connected to the database
# [(0, 'arabic', 'الذي - التي')]
# PostgreSQL connection is closed.

# %% [markdown]
# ## only run this once to import the data

# %%
file_path = "TranslatedWords/arabicData.csv"
table_name = "arabicid"

with open(file_path, encoding='utf-8', newline='') as csvfile:
    csv_reader = csv.reader(csvfile, delimiter=',')
    
    for row in csv_reader:
            # Store the values from the row into separate variables
            id, lang, word = row[0], row[1], row[2]
            # id = int(id)
            insert_word(table_name, id, lang, word)
            # Use the variables as needed
            # print(int, lang,word)
# Out:
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (﻿1,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (2,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (3,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (4,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (5,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (6,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (7,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (8,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (9,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (10,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (11,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (12,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (13,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (14,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (15,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (16,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (17,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (18,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (19,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (20,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (21,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (22,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (23,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (24,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (25,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (26,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (27,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (28,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (29,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (30,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (31,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (32,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (33,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (34,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (35,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (36,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (37,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (38,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (39,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (40,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (41,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (42,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (43,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (44,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (45,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (46,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (47,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (48,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (49,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (50,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (51,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (52,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (53,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (54,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (55,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (56,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (57,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (58,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (59,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (60,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (61,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (62,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (63,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (64,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (65,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (66,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (67,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (68,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (69,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (70,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (71,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (72,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (73,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (74,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (75,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (76,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (77,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (78,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (79,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (80,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (81,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (82,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (83,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (84,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (85,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (86,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (87,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (88,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (89,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (90,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (91,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (92,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (93,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (94,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (95,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (96,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (97,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (98,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (99,{lang},{word});
# PostgreSQL connection is closed.
# connected to the database
# INSERT INTO arabicid (wordid, langauge, word) VALUES (100,{lang},{word});
# PostgreSQL connection is closed.
